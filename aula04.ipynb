# %% [markdown]
# ## GRAFICOS - USANDO SEABORN

# %%
import pandas as pd
import seaborn as sns

# %%
# primeiro armazenar o dataframe em uma variavel

df = pd.read_csv(r'.\data\dataset_techshop_vendas.csv',parse_dates=['data_pedido'])

df.head()
# Out:
#   data_pedido    categoria  preco_unitario  quantidade    regiao  \
# 0  2024-01-01   Acessórios           36.20           1   Sudeste
# 1  2024-01-01   Acessórios          122.61           5   Sudeste
# 2  2024-01-02   Acessórios          151.19           4       Sul
# 3  2024-01-03          TVs         3399.16           2   Sudeste
# 4  2024-01-04  Smartphones         3180.94           2  Nordeste
#
#   canal_marketing  avaliacao
# 0       Instagram        3.3
# 1        Orgânico        4.4
# 2      Google Ads        4.6
# 3      Google Ads        4.1
# 4       Instagram        3.9

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   data_pedido      800 non-null    datetime64[us]
#  1   categoria        800 non-null    str
#  2   preco_unitario   800 non-null    float64
#  3   quantidade       800 non-null    int64
#  4   regiao           800 non-null    str
#  5   canal_marketing  800 non-null    str
#  6   avaliacao        800 non-null    float64
# dtypes: datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 63.1 KB

# %%
#Encontrar espaços em arquivo csvs, pois qualquer espaço no arquivo causa problemas

df.columns.to_list()
# Out:
# ['data_pedido',
#  'categoria',
#  'preco_unitario',
#  'quantidade',
#  'regiao',
#  'canal_marketing',
#  'avaliacao']

# %%
df["faturamento"] = df["preco_unitario"] * df['quantidade']

df.head()
# Out:
#   data_pedido    categoria  preco_unitario  quantidade    regiao  \
# 0  2024-01-01   Acessórios           36.20           1   Sudeste
# 1  2024-01-01   Acessórios          122.61           5   Sudeste
# 2  2024-01-02   Acessórios          151.19           4       Sul
# 3  2024-01-03          TVs         3399.16           2   Sudeste
# 4  2024-01-04  Smartphones         3180.94           2  Nordeste
#
#   canal_marketing  avaliacao  faturamento
# 0       Instagram        3.3        36.20
# 1        Orgânico        4.4       613.05
# 2      Google Ads        4.6       604.76
# 3      Google Ads        4.1      6798.32
# 4       Instagram        3.9      6361.88

# %%
#FIltrar colunas

df[['preco_unitario', 'quantidade', 'faturamento']]
# Out:
#      preco_unitario  quantidade  faturamento
# 0             36.20           1        36.20
# 1            122.61           5       613.05
# 2            151.19           4       604.76
# 3           3399.16           2      6798.32
# 4           3180.94           2      6361.88
# ..              ...         ...          ...
# 795         1128.44           4      4513.76
# 796          209.29           4       837.16
# 797         7979.84           2     15959.68
# 798         4168.01           1      4168.01
# 799          111.95           1       111.95
#
# [800 rows x 3 columns]

# %%
faturamento_total = df['faturamento'].sum()
print(faturamento_total)
# Out:
# 2847624.13

# %%
#Faturamento formatado

print(f'O faturamento foi de {faturamento_total:,.2f}'.replace(',','x').replace('.',',').replace('x','.'))
# Out:
# O faturamento foi de 2.847.624,13

# %%
#ver os atributos da linha

df.loc[100]
# Out:
# data_pedido        2024-03-01 00:00:00
# categoria                  Smartphones
# preco_unitario                 1768.41
# quantidade                           1
# regiao                         Sudeste
# canal_marketing                 E-mail
# avaliacao                          3.4
# faturamento                    1768.41
# Name: 100, dtype: object

# %%
#ver os atributos da linha, com filtro

df.loc[100, 'regiao']
# Out:
# 'Sudeste'

# %%
df.loc[100, 'regiao']
# Out:
# 'Sudeste'

# %%
#criar linha total no final da tabela

#df.loc['total'] = df.sum(numeric_only=True)
#df.tail()

# %%
#Apos tratameto comando para retornar o arquivo a csv apos alterações

df.to_csv('dataset_com_total.csv')

# %%
grafico = sns.countplot(data=df, x='categoria');
grafico.set_title('Pedidos por categoria');
grafico.set_xlabel('categorias');
grafico.set_ylabel('Quantidades');

# %%
grafico = sns.boxplot(data=df, x='categoria', y ='preco_unitario')
grafico.set_title('BoxPlot')
grafico.set_ylabel('Preços')
grafico.set_xlabel('Categorias')
# Out:
# Text(0.5, 0, 'Categorias')

# %%
grafico = sns.histplot(data=df, x='preco_unitario',bins=10,kde=True)

# %%
#Fazer uma copia da planilha original antes de manipular, é melhor!

dfNovo = df.copy()
dfNovo.head()
# Out:
#   data_pedido    categoria  preco_unitario  quantidade    regiao  \
# 0  2024-01-01   Acessórios           36.20           1   Sudeste
# 1  2024-01-01   Acessórios          122.61           5   Sudeste
# 2  2024-01-02   Acessórios          151.19           4       Sul
# 3  2024-01-03          TVs         3399.16           2   Sudeste
# 4  2024-01-04  Smartphones         3180.94           2  Nordeste
#
#   canal_marketing  avaliacao  faturamento
# 0       Instagram        3.3        36.20
# 1        Orgânico        4.4       613.05
# 2      Google Ads        4.6       604.76
# 3      Google Ads        4.1      6798.32
# 4       Instagram        3.9      6361.88
